# %% [markdown]
# # Train BPE Tokenizer
# Train a custom BPE tokenizer

# %% [markdown]
# ## Load and explore dataset obj

# %%
from datasets import load_dataset
from transformers import PreTrainedTokenizerFast

# %%
input_data = load_dataset(path="TucanoBR/Tucano-SFT", cache_dir="../data", split='train')

# %%
type(input_data)

# %%
print(dir(input_data))

# %%
print(input_data)

# %%
input_data[0]

# %% [markdown]
# ## Prepare dataset for training

# %%
# Define a function to extract content from conversations
def extract_content(row):
    # Extract all "content" values from the "conversations" column
    contents_list = [document["content"] for document in row["conversations"] if "content" in document]
    content_texts = ''.join(contents_list)
    return {"content_texts": content_texts}

# %%
# create a new dataset with only text content
dataset = input_data.map(extract_content).select_columns('content_texts')

# %%
print(dataset)

# %%
dataset[0]

# %% [markdown]
# ## First Train

# %%
from tokenizers import Tokenizer, models, pre_tokenizers, decoders, trainers, processors

# %%
vocabulary_size = 15000

# %%
# Create iterator for content_texts
def content_iterator(dataset):
    for row in dataset:
       yield row["content_texts"]

# %%
tokenizer_1 = Tokenizer(models.BPE(unk_token="[UNK]"))
tokenizer_1.pre_tokenizer = pre_tokenizers.Sequence([
    pre_tokenizers.Split(pattern=r'\s+', behavior='removed'),   # Remove whitespace
    pre_tokenizers.Punctuation(behavior='isolated')])           # Isolate punctuation      

# ADD PROPER DECODER
tokenizer_1.decoder = decoders.BPEDecoder(suffix="</w>")

# %%
special_tokens = [
    "[UNK]",      # Unknown token
    "[PAD]",      # Padding token  
    "[EOS]",      # End of sequence
    "<|SYSTEM|>", # System message
    "<|USER|>",   # User message
    "<|ASSISTANT|>", # Assistant message
    "<|END|>",    # End of message
    "<|SEP|>",    # Separator
    "<|EOT|>"]    # End of turn

# %%
# ADD POST-PROCESSOR for special tokens
tokenizer_1.post_processor = processors.TemplateProcessing(
    single="$A [EOS]",
    special_tokens=[("[EOS]", 2)])  # EOS token ID will be 2

# %%
trainer = trainers.BpeTrainer(
    vocab_size=vocabulary_size,
    special_tokens=special_tokens,
    min_frequency=3,
    show_progress=True,
    end_of_word_suffix="</w>",  # Important for proper decoding
    continuing_subword_prefix="")

# %%
# %%time
tokenizer_1.train_from_iterator(content_iterator(dataset), trainer=trainer)

# %%
# Save tokenizer
tokenizer_1.save("portuguese_bpe_tokenizer_7.json")

# %% [markdown]
# ## Explorer trained tokenizer

# %%
encoded = tokenizer_1.encode("Olá, como você está?")
print(encoded.ids)

# %%
tokens_per_line = 20
total_tokens = tokenizer_1.get_vocab_size()
total_lines = int(total_tokens / tokens_per_line)
column_width = 6
print(f'Vocabulary size: {total_tokens}')

# %%
for i in range(0, total_lines):
    token_ids = [(tokens_per_line * i ) + id for id in range(0,tokens_per_line)]
    line = '|'.join(f"{token_id:>{column_width}}" for token_id in token_ids)
    print(line)
    
    tokens = [tokenizer_1.decode([token_id]) for token_id in token_ids]
    line = '|'.join(f"{token:>{column_width}}" for token in tokens)
    print(line, "\n")

# %% [markdown]
# ## Clean out unwanted characters

# %%
remove_chars = []

init_id = 190
end_id = 1932
for i in range(init_id, end_id):
    remove_chars.append(tokenizer_1.decode([i]))

print(remove_chars)

# %%
def remove_row(row, unwanted_chars):
    content = row['content_texts']

    if content is None:
        return True  # Keep rows with None content

    return not any(char in content for char in unwanted_chars)

# %%
dataset

# %%
# %%time

filtered_dataset = dataset.filter(
    lambda example: remove_row(example, remove_chars),
    desc="Filtering out rows with unwanted characters"
)

# %%
filtered_dataset

# %% [markdown]
# ## Second train
# With filtered out row with unwanted characters

# %%
tokenizer_2 = Tokenizer(models.BPE(unk_token="[UNK]"))
tokenizer_2.pre_tokenizer = pre_tokenizers.Sequence([
    pre_tokenizers.Split(pattern=r'\s+', behavior='removed'),   # Remove whitespace
    pre_tokenizers.Punctuation(behavior='isolated')])           # Isolate punctuation      

# ADD PROPER DECODER
tokenizer_2.decoder = decoders.BPEDecoder(suffix="</w>")

# %%
tokenizer_2.post_processor = processors.TemplateProcessing(
    single="$A [EOS]",
    special_tokens=[("[EOS]", 2)])  # EOS token ID will be 2

# %%
trainer = trainers.BpeTrainer(
    vocab_size=vocabulary_size,
    special_tokens=special_tokens,
    min_frequency=3,
    show_progress=True,
    end_of_word_suffix="</w>",  # Important for proper decoding
    continuing_subword_prefix="")

# %%
# %%time
tokenizer_2.train_from_iterator(content_iterator(filtered_dataset), trainer=trainer)

# %%
encoded = tokenizer_2.encode("Olá, como você está?")
print(encoded.ids)

# %%
tokens_per_line = 20
total_tokens = tokenizer_2.get_vocab_size()
total_lines = int(total_tokens / tokens_per_line)
column_width = 6
print(f'Vocabulary size: {total_tokens}')

# %%
for i in range(0, total_lines):
    token_ids = [(tokens_per_line * i ) + id for id in range(0,tokens_per_line)]
    line = '|'.join(f"{token_id:>{column_width}}" for token_id in token_ids)
    print(line)
    
    tokens = [tokenizer_2.decode([token_id]) for token_id in token_ids]
    line = '|'.join(f"{token:>{column_width}}" for token in tokens)
    print(line, "\n")

# %%
# Save tokenizer
tokenizer_2.save("portuguese_bpe_tokenizer_8.json")

# %%
# Create a PreTrainedTokenizerFast wrapper from your trained tokenizer
#hf_tokenizer = PreTrainedTokenizerFast(tokenizer_object=tokenizer)

hf_tokenizer = PreTrainedTokenizerFast(
    tokenizer_object=tokenizer_2,
    unk_token="[UNK]",
    pad_token="[PAD]", 
    eos_token="[EOS]",
    clean_up_tokenization_spaces=True,  # CRITICAL!
    model_max_length=512)

# %%
chat_tokens = {
    'additional_special_tokens': [
        "<|SYSTEM|>", 
        "<|USER|>", 
        "<|ASSISTANT|>", 
        "<|END|>", 
        "<|SEP|>", 
        "<|EOT|>"]}

# %%
hf_tokenizer.add_special_tokens(chat_tokens)

# %%
print("\n" + "="*80)
print("TESTING CHAT TOKENIZER")
print("="*80)

# Test regular Portuguese text
regular_texts = [
    "Astronomia é uma ciência natural",
    "São Tomé e Príncipe", 
    "Olá, como você está?",
    "Python é uma linguagem de programação."
]

print("REGULAR TEXT ROUNDTRIP TESTS:")
print("-" * 50)

for text in regular_texts:
    tokens = hf_tokenizer.encode(text, add_special_tokens=False)
    decoded = hf_tokenizer.decode(tokens, skip_special_tokens=True)
    
    print(f"Original: '{text}'")
    print(f"Decoded:  '{decoded}'") 
    print(f"Match:    {text == decoded}")
    print(f"Tokens:   {hf_tokenizer.tokenize(text)}")
    print("-" * 40)

# %%
print("\nSPECIAL TOKEN IDs:")
print("-" * 50)
special_tokens = ["[UNK]", "[PAD]", "[EOS]", "<|SYSTEM|>", "<|USER|>", 
                 "<|ASSISTANT|>", "<|END|>", "<|SEP|>", "<|EOT|>"]

for token in special_tokens:
    try:
        token_id = hf_tokenizer.convert_tokens_to_ids(token)
        print(f"'{token}' -> ID: {token_id}")
    except Exception as e:
        print(f"'{token}' -> ERROR: {e}")

# %%
# Test chat format
print("\nCHAT FORMAT TESTS:")
print("-" * 50)

chat_examples = [
    "<|SYSTEM|>Você é um assistente prestativo.<|END|>",
    "<|USER|>Qual é a capital do Brasil?<|END|>",
    "<|ASSISTANT|>A capital do Brasil é Brasília.<|END|>",
    "<|SYSTEM|>Sistema iniciado<|SEP|><|USER|>Oi!<|SEP|><|ASSISTANT|>Olá!<|EOT|>"
]

for text in chat_examples:
    tokens = hf_tokenizer.encode(text, add_special_tokens=False)
    decoded = hf_tokenizer.decode(tokens, skip_special_tokens=True)
    
    print(f"Original: '{text}'")
    print(f"Decoded:  '{decoded}'")
    print(f"Match:    {text == decoded}")
    print(f"Token IDs: {tokens}")
    print("-" * 40)

# %%
# Save tokenizer
hf_tokenizer.save_pretrained("../models/30k/")

# %% [markdown]
# ## Third train

# %%
seed = 8483
num_samples = 200000
prepared_data = filtered_dataset.shuffle(seed).select(range(num_samples))

# %%
tokenizer_3 = Tokenizer(models.BPE(unk_token="[UNK]"))
tokenizer_3.pre_tokenizer = pre_tokenizers.Sequence([
    pre_tokenizers.Split(pattern=r'\s+', behavior='removed'),   # Remove whitespace
    pre_tokenizers.Punctuation(behavior='isolated')])           # Isolate punctuation      

# ADD PROPER DECODER
tokenizer_3.decoder = decoders.BPEDecoder(suffix="</w>")

# %%
tokenizer_3.post_processor = processors.TemplateProcessing(
    single="$A [EOS]",
    special_tokens=[("[EOS]", 2)])  # EOS token ID will be 2

# %%
# %%time
tokenizer_3.train_from_iterator(content_iterator(prepared_data), trainer=trainer)

# %%
encoded = tokenizer.encode("Olá, como você está?")
print(encoded.ids)

# %%
tokens_per_line = 20
total_tokens = tokenizer_3.get_vocab_size()
total_lines = int(total_tokens / tokens_per_line)
column_width = 6
print(f'Vocabulary size: {total_tokens}')

# %%
for i in range(0, total_lines):
    token_ids = [(tokens_per_line * i ) + id for id in range(0,tokens_per_line)]
    line = '|'.join(f"{token_id:>{column_width}}" for token_id in token_ids)
    print(line)
    
    tokens = [tokenizer.decode([token_id]) for token_id in token_ids]
    line = '|'.join(f"{token:>{column_width}}" for token in tokens)
    print(line, "\n")

# %%
# Save tokenizer
tokenizer_3.save("portuguese_bpe_tokenizer_9.json")

# %% [markdown]
# Tokenizers parameters:
# | Name | Vocab Size | sample size |
# |------|------------|-------------|
# | 1    | 30,000     | 679,609     |
# | 2    | 30,000     | 657,685     |
# | 3    | 30,000     | 200,000     |
# | 4    | 15,000     | 679,609     |
# | 5    | 15,000     | 657,685     |
# | 6    | 15,000     | 200,000     |
# | 7    | 60,000     | 679,609     |
# | 8    | 60,000     | 657,685     |
# | 9    | 60,000     | 200,000     |
